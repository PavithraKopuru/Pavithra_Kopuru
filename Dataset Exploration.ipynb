# %%
import pandas as pd

# %%
california = pd.read_csv(r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\housing.csv")
world = pd.read_csv(r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\world_real_estate_data(147k).csv")
indian_cities = pd.read_csv(r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\Real Estate Data V21.csv")
indian_prices = pd.read_csv(r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\real_estate_dataset.csv")

# %%
print(california.head())
print(world.head())
print(indian_cities.head())
print(indian_prices.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#                                                title   country  \
# 0  2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1              4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2          1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3             1 room apartment  in Pattaya, Thailand  Thailand
# 4             2 room apartment  in Pattaya, Thailand  Thailand
#
#                                     location  building_construction_year  \
# 0               Mediterranean Region, Turkey                         NaN
# 1  Kalkan, Mediterranean Region, Kas, Turkey                      2021.0
# 2      Mediterranean Region, Antalya, Turkey                         NaN
# 3      Chon Buri Province, Pattaya, Thailand                      2020.0
# 4      Chon Buri Province, Pattaya, Thailand                      2026.0
#
#    building_total_floors  apartment_floor  apartment_rooms  \
# 0                    5.0              1.0              3.0
# 1                    2.0              NaN              NaN
# 2                    5.0              2.0              2.0
# 3                   15.0              5.0              2.0
# 4                    8.0              3.0              3.0
#
#    apartment_bedrooms  apartment_bathrooms apartment_total_area  \
# 0                 2.0                  2.0               120 m²
# 1                 NaN                  NaN               500 m²
# 2                 1.0                  1.0                65 m²
# 3                 1.0                  1.0                  NaN
# 4                 2.0                  1.0                  NaN
#
#   apartment_living_area  price_in_USD  \
# 0                110 m²      315209.0
# 1                480 m²     1108667.0
# 2                 60 m²      173211.0
# 3                 40 m²       99900.0
# 4                 36 m²       67000.0
#
#                                                image  \
# 0  https://realting.com/uploads/bigSlider/ab3/888...
# 1  https://realting.com/uploads/bigSlider/87b/679...
# 2  https://realting.com/uploads/bigSlider/030/a11...
# 3  https://realting.com/uploads/bigSlider/e9a/e06...
# 4  https://realting.com/uploads/bigSlider/453/aa2...
#
#                                                  url
# 0  https://realting.com/property-for-sale/turkey/...
# 1  https://realting.com/property-for-sale/turkey/...
# 2  https://realting.com/property-for-sale/turkey/...
# 3  https://realting.com/property-for-sale/thailan...
# 4  https://realting.com/property-for-sale/thailan...
#                                       Name  \
# 0                         Casagrand ECR 14
# 1    Ramanathan Nagar, Pozhichalur,Chennai
# 2                              DAC Prapthi
# 3  Naveenilaya,Chepauk, Triplicane,Chennai
# 4                 VGN Spring Field Phase 1
#
#                                       Property Title     Price  \
# 0  4 BHK Flat for sale in Kanathur Reddikuppam, C...  ₹1.99 Cr
# 1  10 BHK Independent House for sale in Pozhichal...  ₹2.25 Cr
# 2      3 BHK Flat for sale in West Tambaram, Chennai   ₹1.0 Cr
# 3  7 BHK Independent House for sale in Triplicane...  ₹3.33 Cr
# 4              2 BHK Flat for sale in Avadi, Chennai   ₹48.0 L
#
#                                    Location  Total_Area  Price_per_SQFT  \
# 0             Kanathur Reddikuppam, Chennai        2583          7700.0
# 1     Ramanathan Nagar, Pozhichalur,Chennai        7000          3210.0
# 2  Kasthuribai Nagar, West Tambaram,Chennai        1320          7580.0
# 3   Naveenilaya,Chepauk, Triplicane,Chennai        4250          7840.0
# 4                            Avadi, Chennai         960          5000.0
#
#                                          Description  Baths Balcony
# 0  Best 4 BHK Apartment for modern-day lifestyle ...      4     Yes
# 1  Looking for a 10 BHK Independent House for sal...      6     Yes
# 2  Property for sale in Tambaram, Chennai. This 3...      3      No
# 3  Entire Building for sale with 7 units of singl...      5     Yes
# 4  Property for sale in Avadi, Chennai. This 2 BH...      3     Yes
#                                                  url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def explore(df, name):
    print(f"\n===== {name} Dataset =====")
    print("Shape:", df.shape)
    print("\nMissing values:\n", df.isnull().sum())
    print("\nBasic statistics:\n", df.describe(include='all').T)
    print("\nFirst 5 rows:\n", df.head())

# %%
# Call for each dataset
explore(california, "California Housing")
explore(world, "World Real Estate")
explore(indian_cities, "Indian Cities")
explore(indian_prices, "Indian Prices")
# Out:
# ===== California Housing Dataset =====
# Shape: (20640, 10)
#
# Missing values:
#  longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
#
# Basic statistics:
#                        count unique        top  freq           mean  \
# longitude           20640.0    NaN        NaN   NaN    -119.569704
# latitude            20640.0    NaN        NaN   NaN      35.631861
# housing_median_age  20640.0    NaN        NaN   NaN      28.639486
# total_rooms         20640.0    NaN        NaN   NaN    2635.763081
# total_bedrooms      20433.0    NaN        NaN   NaN     537.870553
# population          20640.0    NaN        NaN   NaN    1425.476744
# households          20640.0    NaN        NaN   NaN      499.53968
# median_income       20640.0    NaN        NaN   NaN       3.870671
# median_house_value  20640.0    NaN        NaN   NaN  206855.816909
# ocean_proximity       20640      5  <1H OCEAN  9136            NaN
#
#                               std      min       25%       50%       75%  \
# longitude                2.003532  -124.35    -121.8   -118.49   -118.01
# latitude                 2.135952    32.54     33.93     34.26     37.71
# housing_median_age      12.585558      1.0      18.0      29.0      37.0
# total_rooms           2181.615252      2.0   1447.75    2127.0    3148.0
# total_bedrooms          421.38507      1.0     296.0     435.0     647.0
# population            1132.462122      3.0     787.0    1166.0    1725.0
# households             382.329753      1.0     280.0     409.0     605.0
# median_income            1.899822   0.4999    2.5634    3.5348   4.74325
# median_house_value  115395.615874  14999.0  119600.0  179700.0  264725.0
# ocean_proximity               NaN      NaN       NaN       NaN       NaN
#
#                          max
# longitude            -114.31
# latitude               41.95
# housing_median_age      52.0
# total_rooms          39320.0
# total_bedrooms        6445.0
# population           35682.0
# households            6082.0
# median_income        15.0001
# median_house_value  500001.0
# ocean_proximity          NaN
#
# First 5 rows:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
# ===== World Real Estate Dataset =====
# Shape: (147536, 14)
#
# Missing values:
#  title                              0
# country                          130
# location                         131
# building_construction_year     82817
# building_total_floors          79312
# apartment_floor                92944
# apartment_rooms                73358
# apartment_bedrooms            110554
# apartment_bathrooms            91563
# apartment_total_area            5740
# apartment_living_area         119824
# price_in_USD                    2575
# image                              0
# url                                0
# dtype: int64
#
# Basic statistics:
#                                 count  unique  \
# title                         147536   78292
# country                       147406      27
# location                      147405    7445
# building_construction_year   64719.0     NaN
# building_total_floors        68224.0     NaN
# apartment_floor              54592.0     NaN
# apartment_rooms              74178.0     NaN
# apartment_bedrooms           36982.0     NaN
# apartment_bathrooms          55973.0     NaN
# apartment_total_area          141796    1492
# apartment_living_area          27712     641
# price_in_USD                144961.0     NaN
# image                         147536  113753
# url                           147536  147536
#
#                                                                           top  \
# title                       1 room apartment 24 m² in poselenie Sosenskoe,...
# country                                                                Turkey
# location                    Mediterranean Region, Sekerhane Mahallesi, Ala...
# building_construction_year                                                NaN
# building_total_floors                                                     NaN
# apartment_floor                                                           NaN
# apartment_rooms                                                           NaN
# apartment_bedrooms                                                        NaN
# apartment_bathrooms                                                       NaN
# apartment_total_area                                                   100 m²
# apartment_living_area                                                   30 m²
# price_in_USD                                                              NaN
# image                       https://realting.com/uploads/bigSlider/9b9/e2b...
# url                         https://realting.com/property-for-sale/turkey/...
#
#                              freq           mean            std  min  \
# title                         486            NaN            NaN  NaN
# country                     25724            NaN            NaN  NaN
# location                     7244            NaN            NaN  NaN
# building_construction_year    NaN    1996.921754     157.527635  1.0
# building_total_floors         NaN       8.575692       8.356781 -1.0
# apartment_floor               NaN       5.791709       5.541368 -2.0
# apartment_rooms               NaN       2.572097       1.319545 -1.0
# apartment_bedrooms            NaN       2.289222      18.276913 -1.0
# apartment_bathrooms           NaN       1.364229       0.745019  1.0
# apartment_total_area         2468            NaN            NaN  NaN
# apartment_living_area         888            NaN            NaN  NaN
# price_in_USD                  NaN  412172.179138  842098.411382  0.0
# image                        1219            NaN            NaN  NaN
# url                             1            NaN            NaN  NaN
#
#                                  25%       50%       75%         max
# title                            NaN       NaN       NaN         NaN
# country                          NaN       NaN       NaN         NaN
# location                         NaN       NaN       NaN         NaN
# building_construction_year    2004.0    2021.0    2024.0      2316.0
# building_total_floors            2.0       5.0      14.0       124.0
# apartment_floor                  2.0       4.0       8.0       202.0
# apartment_rooms                  2.0       2.0       3.0       124.0
# apartment_bedrooms               1.0       2.0       3.0      2009.0
# apartment_bathrooms              1.0       1.0       2.0        43.0
# apartment_total_area             NaN       NaN       NaN         NaN
# apartment_living_area            NaN       NaN       NaN         NaN
# price_in_USD                105420.0  190212.0  398930.0  30602832.0
# image                            NaN       NaN       NaN         NaN
# url                              NaN       NaN       NaN         NaN
#
# First 5 rows:
#                                                 title   country  \
# 0  2 room apartment 120 m² in Mediterranean Regio...    Turkey
# 1              4 room villa 500 m² in Kalkan, Turkey    Turkey
# 2          1 room apartment 65 m² in Antalya, Turkey    Turkey
# 3             1 room apartment  in Pattaya, Thailand  Thailand
# 4             2 room apartment  in Pattaya, Thailand  Thailand
#
#                                     location  building_construction_year  \
# 0               Mediterranean Region, Turkey                         NaN
# 1  Kalkan, Mediterranean Region, Kas, Turkey                      2021.0
# 2      Mediterranean Region, Antalya, Turkey                         NaN
# 3      Chon Buri Province, Pattaya, Thailand                      2020.0
# 4      Chon Buri Province, Pattaya, Thailand                      2026.0
#
#    building_total_floors  apartment_floor  apartment_rooms  \
# 0                    5.0              1.0              3.0
# 1                    2.0              NaN              NaN
# 2                    5.0              2.0              2.0
# 3                   15.0              5.0              2.0
# 4                    8.0              3.0              3.0
#
#    apartment_bedrooms  apartment_bathrooms apartment_total_area  \
# 0                 2.0                  2.0               120 m²
# 1                 NaN                  NaN               500 m²
# 2                 1.0                  1.0                65 m²
# 3                 1.0                  1.0                  NaN
# 4                 2.0                  1.0                  NaN
#
#   apartment_living_area  price_in_USD  \
# 0                110 m²      315209.0
# 1                480 m²     1108667.0
# 2                 60 m²      173211.0
# 3                 40 m²       99900.0
# 4                 36 m²       67000.0
#
#                                                image  \
# 0  https://realting.com/uploads/bigSlider/ab3/888...
# 1  https://realting.com/uploads/bigSlider/87b/679...
# 2  https://realting.com/uploads/bigSlider/030/a11...
# 3  https://realting.com/uploads/bigSlider/e9a/e06...
# 4  https://realting.com/uploads/bigSlider/453/aa2...
#
#                                                  url
# 0  https://realting.com/property-for-sale/turkey/...
# 1  https://realting.com/property-for-sale/turkey/...
# 2  https://realting.com/property-for-sale/turkey/...
# 3  https://realting.com/property-for-sale/thailan...
# 4  https://realting.com/property-for-sale/thailan...
#
# ===== Indian Cities Dataset =====
# Shape: (14528, 9)
#
# Missing values:
#  Name              0
# Property Title    0
# Price             0
# Location          0
# Total_Area        0
# Price_per_SQFT    0
# Description       0
# Baths             0
# Balcony           0
# dtype: int64
#
# Basic statistics:
#                    count unique  \
# Name              14528   9998
# Property Title    14528   6507
# Price             14528    891
# Location          14528   7050
# Total_Area      14528.0    NaN
# Price_per_SQFT  14528.0    NaN
# Description       14528  14490
# Baths           14528.0    NaN
# Balcony           14528      2
#
#                                                               top  freq  \
# Name                                            Classic Apartment    42
# Property Title  2 BHK Flat for sale in Electronic City, Bangalore    53
# Price                                                     ₹60.0 L   407
# Location                              Sector 12 Dwarka, New Delhi    44
# Total_Area                                                    NaN   NaN
# Price_per_SQFT                                                NaN   NaN
# Description     Premier Inspira Maplewood in Sarjapur Road, Ba...     5
# Baths                                                         NaN   NaN
# Balcony                                                       Yes  8580
#
#                         mean           std   min     25%     50%     75%  \
# Name                     NaN           NaN   NaN     NaN     NaN     NaN
# Property Title           NaN           NaN   NaN     NaN     NaN     NaN
# Price                    NaN           NaN   NaN     NaN     NaN     NaN
# Location                 NaN           NaN   NaN     NaN     NaN     NaN
# Total_Area       1297.916988   1245.694305  70.0   650.0  1000.0  1439.0
# Price_per_SQFT  11719.456222  49036.068632   0.0  4480.0  6050.0  9312.5
# Description              NaN           NaN   NaN     NaN     NaN     NaN
# Baths               2.751239      0.898243   1.0     2.0     3.0     3.0
# Balcony                  NaN           NaN   NaN     NaN     NaN     NaN
#
#                      max
# Name                 NaN
# Property Title       NaN
# Price                NaN
# Location             NaN
# Total_Area       35000.0
# Price_per_SQFT  999000.0
# Description          NaN
# Baths                6.0
# Balcony              NaN
#
# First 5 rows:
#                                        Name  \
# 0                         Casagrand ECR 14
# 1    Ramanathan Nagar, Pozhichalur,Chennai
# 2                              DAC Prapthi
# 3  Naveenilaya,Chepauk, Triplicane,Chennai
# 4                 VGN Spring Field Phase 1
#
#                                       Property Title     Price  \
# 0  4 BHK Flat for sale in Kanathur Reddikuppam, C...  ₹1.99 Cr
# 1  10 BHK Independent House for sale in Pozhichal...  ₹2.25 Cr
# 2      3 BHK Flat for sale in West Tambaram, Chennai   ₹1.0 Cr
# 3  7 BHK Independent House for sale in Triplicane...  ₹3.33 Cr
# 4              2 BHK Flat for sale in Avadi, Chennai   ₹48.0 L
#
#                                    Location  Total_Area  Price_per_SQFT  \
# 0             Kanathur Reddikuppam, Chennai        2583          7700.0
# 1     Ramanathan Nagar, Pozhichalur,Chennai        7000          3210.0
# 2  Kasthuribai Nagar, West Tambaram,Chennai        1320          7580.0
# 3   Naveenilaya,Chepauk, Triplicane,Chennai        4250          7840.0
# 4                            Avadi, Chennai         960          5000.0
#
#                                          Description  Baths Balcony
# 0  Best 4 BHK Apartment for modern-day lifestyle ...      4     Yes
# 1  Looking for a 10 BHK Independent House for sal...      6     Yes
# 2  Property for sale in Tambaram, Chennai. This 3...      3      No
# 3  Entire Building for sale with 7 units of singl...      5     Yes
# 4  Property for sale in Avadi, Chennai. This 2 BH...      3     Yes
#
# ===== Indian Prices Dataset =====
# Shape: (287, 9)
#
# Missing values:
#  url             0
# beds            0
# city            0
# date            0
# size            0
# type            0
# baths           0
# price           0
# neighborhood    0
# dtype: int64
#
# Basic statistics:
#                count unique                                                top  \
# url             287    280  https://www.99acres.com/5-bhk-bedroom-independ...
# beds          287.0    NaN                                                NaN
# city            287     26                                           Kakinada
# date            287     25                                         2025-02-19
# size            287    211                                             Varies
# type            287     48                            Residential land / Plot
# baths         287.0    NaN                                                NaN
# price         287.0    NaN                                                NaN
# neighborhood    287    224                     Noida Greater Noida Expressway
#
#              freq            mean              std  min        25%  \
# url             3             NaN              NaN  NaN        NaN
# beds          NaN        2.156794         1.767959  0.0        0.0
# city           37             NaN              NaN  NaN        NaN
# date          155             NaN              NaN  NaN        NaN
# size           24             NaN              NaN  NaN        NaN
# type           47             NaN              NaN  NaN        NaN
# baths         NaN        1.526132         1.771525  0.0        0.0
# price         NaN  19564337.69216  44617994.515882  0.0  4738000.0
# neighborhood    8             NaN              NaN  NaN        NaN
#
#                      50%         75%          max
# url                  NaN         NaN          NaN
# beds                 2.0         3.0         12.0
# city                 NaN         NaN          NaN
# date                 NaN         NaN          NaN
# size                 NaN         NaN          NaN
# type                 NaN         NaN          NaN
# baths                1.0         2.0         12.0
# price         10000000.0  20850000.0  600000000.0
# neighborhood         NaN         NaN          NaN
#
# First 5 rows:
#                                                   url  beds       city  \
# 0  https://www.99acres.com/residential-land-plot-...     0  Bangalore
# 1  https://www.99acres.com/2-bhk-bedroom-apartmen...     2  Bangalore
# 2  https://www.99acres.com/sumadhura-capitol-resi...     3  Bangalore
# 3  https://www.99acres.com/provident-botanico-sou...     2  Bangalore
# 4  https://www.99acres.com/kvg-superior-kalkere-b...     2  Bangalore
#
#          date            size                     type  baths       price  \
# 0  2025-02-19   799-1258 sqft  Residential land / Plot      0   2317000.0
# 1  2025-02-19       1085 sqft               2 BHK Flat      2  12500000.0
# 2  2025-02-19  1525-2150 sqft       3, 4 BHK Apartment      0  23200000.0
# 3  2025-02-19   658-1003 sqft       2, 3 BHK Apartment      0    889000.0
# 4  2025-02-19  1179-1449 sqft       2, 3 BHK Apartment      0   6483000.0
#
#   neighborhood
# 0       Jigani
# 1  Tumkur Road
# 2   Whitefield
# 3  Soukya Road
# 4      Kalkere

# %%
# Example visualization
plt.figure(figsize=(6,4))
sns.histplot(california["median_house_value"], bins=50, kde=True)
plt.title("California House Value Distribution")
plt.show()

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.8/12.8 MB 2.1 MB/s eta 0:00:06
#      ---- ----------------------------------- 1.6/12.8 MB 2.7 MB/s eta 0:00:05
#      ------- -------------------------------- 2.4/12.8 MB 2.9 MB/s eta 0:00:04
#      -------- ------------------------------- 2.6/12.8 MB 3.0 MB/s eta 0:00:04
#      ---------- ----------------------------- 3.4/12.8 MB 2.7 MB/s eta 0:00:04
#      ------------- -------------------------- 4.5/12.8 MB 3.0 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 3.1 MB/s eta 0:00:03
#      ------------------ --------------------- 6.0/12.8 MB 3.3 MB/s eta 0:00:03
#      ---------------------- ----------------- 7.1/12.8 MB 3.5 MB/s eta 0:00:02
#      ------------------------ --------------- 7.9/12.8 MB 3.4 MB/s eta 0:00:02
#      -------------------------- ------------- 8.4/12.8 MB 3.4 MB/s eta 0:00:02
#      ----------------------------- ---------- 9.4/12.8 MB 3.5 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 3.5 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.5 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.5 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 3.4 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.3 MB/s  0:00:04
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import re
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
# Read your dataset
indian_cities = pd.read_csv(
    r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\Real Estate Data V21.csv"
)

# Quick look at the data
indian_cities.head()
# Out:
#                                       Name  \
# 0                         Casagrand ECR 14
# 1    Ramanathan Nagar, Pozhichalur,Chennai
# 2                              DAC Prapthi
# 3  Naveenilaya,Chepauk, Triplicane,Chennai
# 4                 VGN Spring Field Phase 1
#
#                                       Property Title     Price  \
# 0  4 BHK Flat for sale in Kanathur Reddikuppam, C...  ₹1.99 Cr
# 1  10 BHK Independent House for sale in Pozhichal...  ₹2.25 Cr
# 2      3 BHK Flat for sale in West Tambaram, Chennai   ₹1.0 Cr
# 3  7 BHK Independent House for sale in Triplicane...  ₹3.33 Cr
# 4              2 BHK Flat for sale in Avadi, Chennai   ₹48.0 L
#
#                                    Location  Total_Area  Price_per_SQFT  \
# 0             Kanathur Reddikuppam, Chennai        2583          7700.0
# 1     Ramanathan Nagar, Pozhichalur,Chennai        7000          3210.0
# 2  Kasthuribai Nagar, West Tambaram,Chennai        1320          7580.0
# 3   Naveenilaya,Chepauk, Triplicane,Chennai        4250          7840.0
# 4                            Avadi, Chennai         960          5000.0
#
#                                          Description  Baths Balcony
# 0  Best 4 BHK Apartment for modern-day lifestyle ...      4     Yes
# 1  Looking for a 10 BHK Independent House for sal...      6     Yes
# 2  Property for sale in Tambaram, Chennai. This 3...      3      No
# 3  Entire Building for sale with 7 units of singl...      5     Yes
# 4  Property for sale in Avadi, Chennai. This 2 BH...      3     Yes

# %%
# Mapping for text-based numbers
TEXT_NUMBERS = {
    "one": 1, "two": 2, "three": 3, "four": 4, "five": 5,
    "six": 6, "seven": 7, "eight": 8, "nine": 9, "ten": 10
}

# Regex patterns for common cases
ROOM_PATTERNS = [
    r'(\d+)\s*bhk',
    r'(\d+)\s*bed(?:room)?\b',
    r'(\d+)\s*br\b',
    r'(\d+)\s*rk\b'
]

def extract_rooms(text):
    if not isinstance(text, str):
        return None
    text_lower = text.lower()

    # 1. Regex direct match
    for pat in ROOM_PATTERNS:
        match = re.search(pat, text_lower)
        if match:
            return int(match.group(1))

    # 2. Spelled-out numbers
    doc = nlp(text_lower)
    for i, token in enumerate(doc):
        if token.text in TEXT_NUMBERS:
            if i + 1 < len(doc):
                next_word = doc[i + 1].text
                if next_word in ["bhk", "bedroom", "bed", "br", "rk"]:
                    return TEXT_NUMBERS[token.text]

    # 3. Fallback: numeric token + room word
    for tok, nxt in zip(doc, doc[1:]):
        if tok.like_num and nxt.text in ["bhk", "bedroom", "bed", "br", "rk"]:
            try:
                return int(tok.text)
            except ValueError:
                pass

    return None

# %%
print(indian_cities.columns.tolist())
indian_cities["num_rooms"] = indian_cities["Description"].apply(extract_rooms)
indian_cities[["Description", "num_rooms"]].head(20)
# Out:
# ['Name', 'Property Title', 'Price', 'Location', 'Total_Area', 'Price_per_SQFT', 'Description', 'Baths', 'Balcony', 'num_rooms']
#                                           Description  num_rooms
# 0   Best 4 BHK Apartment for modern-day lifestyle ...        4.0
# 1   Looking for a 10 BHK Independent House for sal...       10.0
# 2   Property for sale in Tambaram, Chennai. This 3...        3.0
# 3   Entire Building for sale with 7 units of singl...        7.0
# 4   Property for sale in Avadi, Chennai. This 2 BH...        2.0
# 5   Price negotiable. Big hall, big balcony, gated...        2.0
# 6   2 BHK Apartment for sale in Chennai. This prop...        2.0
# 7   A 3 BHK Independent House for sale in Mahindra...        3.0
# 8   Check out this 2 BHK Apartment for sale in Tam...        2.0
# 9   We are the proud owners of this 1 bhk apartmen...        1.0
# 10  A 1 BHK Apartment for sale in Mahindra World C...        1.0
# 11  Looking for a 3 BHK Apartment for sale in Chen...        3.0
# 12  Looking for a 6 BHK Villa for sale in Chennai?...        6.0
# 13  13a,4th Street, Ragavan colony, Ashok Nagar, C...        2.0
# 14  Best 2 BHK Apartment for modern-day lifestyle ...        2.0
# 15  Situated at Alapakkam, New Perungalathur. SURR...        3.0
# 16  Check out this 2 BHK Apartment for sale in Pad...        2.0
# 17  Best 3 BHK Apartment for modern-day lifestyle ...        3.0
# 18  Best 4 BHK Apartment for modern-day lifestyle ...        4.0
# 19  2 BHK Independent House for sale in Pozhichalu...        2.0

# %%
print("Total entries:", len(indian_cities))
print("Extracted room counts:", indian_cities['num_rooms'].notnull().sum())
print("Missing room counts:", indian_cities['num_rooms'].isnull().sum())
# Out:
# Total entries: 14528
# Extracted room counts: 14347
# Missing room counts: 181

# %%
indian_cities.to_csv(
    r"C:\Users\pavit\Downloads\OneDrive\Documents\World Real Estate Data\Real Estate Data V21_with_rooms.csv",
    index=False
)
print("✅ File saved with new column 'num_rooms'")
# Out:
# ✅ File saved with new column 'num_rooms'
